# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1')

# %%
df2 = pd.read_csv('df2')

# %%
df1.rename( columns={'Unnamed: 0':'Time'}, inplace=True )

# %%
df1.head()
# Out:
#          Time         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins=15)

# %%
df2['b'].plot(kind='hist')

# %%
df1['C'].plot.hist()

# %%
df2.plot.area(alpha = 0.4)

# %%
df2.plot.bar() # pass stacked = True

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1.plot.line(x = 'Time',y= 'B', lw =1)

# %%
a = df1.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# Unnamed: 0    1000 non-null object
# A             1000 non-null float64
# B             1000 non-null float64
# C             1000 non-null float64
# D             1000 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
# df1.plot.scatter(x='A', y = 'B', c='C', cmap='twilight')
df1.plot.scatter(x='A', y = 'B', s = df1['C']*100)

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['a','b'])

# %%
df.plot.hexbin(x='a',y='b', gridsize=20, cmap="plasma")

# %%
# df.plot.kde()
df2.plot.density()
